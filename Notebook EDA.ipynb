# %% [markdown]
# ## Notebook proyecto EDA

# %%
import pandas as pd
import numpy as np

# %%
pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_excel('C:/Users/vgonz/Documents/the bridge/prueba_git/02-Data_analysis/proyecto eda empleabilidad/tasa_actividad_de_25-64.xlsx', engine='openpyxl')
df.head()
# Out:
#                  AMBOS SEXOS  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0                      TOTAL         NaN         NaN         NaN         NaN
# 1                       2021   2020.0000   2019.0000   2018.0000   2017.0000
# 2   25 - 64 años         NaN         NaN         NaN         NaN         NaN
# 3          TOTAL     81.5179     79.9435     81.0298     80.8341     80.8930
# 4      Andalucía     78.0396     75.7452     76.9738     76.9808     77.3247
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8                         Unnamed: 9  ...  \
# 0         NaN         NaN         NaN  Inferior a 2ª etapa E. Secundaria  ...
# 1   2016.0000   2015.0000   2014.0000                               2021  ...
# 2         NaN         NaN         NaN                                NaN  ...
# 3     81.2496     81.0707     80.7495                            72.5281  ...
# 4     77.9173     78.4683     78.1372                            70.6844  ...
#
# ...

# %%
df=df.set_index(' ')
df
# Out:
#                                 AMBOS SEXOS  Unnamed: 2  Unnamed: 3  \
#
#                                       TOTAL         NaN         NaN
#                                        2021   2020.0000   2019.0000
# 25 - 64 años                            NaN         NaN         NaN
#     TOTAL                           81.5179     79.9435     81.0298
#     Andalucía                       78.0396     75.7452     76.9738
# ...                                     ...         ...         ...
#     Murcia, Región de               66.0463     64.1475     61.1206
#     Navarra, Comunidad Foral de     67.5998     63.2547     61.9974
#     País Vasco                      65.7936     63.2311     60.4594
#     Rioja, La                        68.591     66.9937     66.6335
#     Ceuta y Melilla                 68.2434     68.6546     63.0546
#
#                                  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
#
#                                         NaN         NaN         NaN
# ...

# %%
df
# Out:
#                                 AMBOS SEXOS  Unnamed: 2  Unnamed: 3  \
#
#                                       TOTAL         NaN         NaN
#                                        2021   2020.0000   2019.0000
# 25 - 64 años                            NaN         NaN         NaN
#     TOTAL                           81.5179     79.9435     81.0298
#     Andalucía                       78.0396     75.7452     76.9738
# ...                                     ...         ...         ...
#     Murcia, Región de               66.0463     64.1475     61.1206
#     Navarra, Comunidad Foral de     67.5998     63.2547     61.9974
#     País Vasco                      65.7936     63.2311     60.4594
#     Rioja, La                        68.591     66.9937     66.6335
#     Ceuta y Melilla                 68.2434     68.6546     63.0546
#
#                                  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
#
#                                         NaN         NaN         NaN
# ...

# %%
df.isnull().mean()
# Out:
# AMBOS SEXOS    0.049020
# Unnamed: 2     0.058824
# Unnamed: 3     0.058824
# Unnamed: 4     0.058824
# Unnamed: 5     0.058824
#                  ...
# Unnamed: 92    0.058824
# Unnamed: 93    0.058824
# Unnamed: 94    0.058824
# Unnamed: 95    0.058824
# Unnamed: 96    0.058824
# Length: 96, dtype: float64

# %% [markdown]
# Voy a crear una nueva tabla con el intervalos de 25-64 años de ambos géneros

# %%
ambos=df.iloc[0:22,0:32]
ambos
# Out:
#                                 AMBOS SEXOS  Unnamed: 2  Unnamed: 3  \
#
#                                       TOTAL         NaN         NaN
#                                        2021   2020.0000   2019.0000
# 25 - 64 años                            NaN         NaN         NaN
#     TOTAL                           81.5179     79.9435     81.0298
#     Andalucía                       78.0396     75.7452     76.9738
#     Aragón                          83.8101     82.5463     84.0779
#     Asturias, Principado de         76.6549     75.2735     75.3420
#     Balears, Illes                  83.6156     80.6136     82.7619
#     Canarias                        77.5728     75.9111     78.7184
#     Cantabria                       80.5055     78.1394     79.3835
#     Castilla y León                 80.9962     79.9130     81.0874
#     Castilla-La Mancha              81.4917     79.2114     80.2528
#     Cataluña                         84.236     82.9133     83.8838
# ...

# %%
ambos
# Out:
#                                 AMBOS SEXOS  Unnamed: 2  Unnamed: 3  \
#
#                                       TOTAL         NaN         NaN
#                                        2021   2020.0000   2019.0000
# 25 - 64 años                            NaN         NaN         NaN
#     TOTAL                           81.5179     79.9435     81.0298
#     Andalucía                       78.0396     75.7452     76.9738
#     Aragón                          83.8101     82.5463     84.0779
#     Asturias, Principado de         76.6549     75.2735     75.3420
#     Balears, Illes                  83.6156     80.6136     82.7619
#     Canarias                        77.5728     75.9111     78.7184
#     Cantabria                       80.5055     78.1394     79.3835
#     Castilla y León                 80.9962     79.9130     81.0874
#     Castilla-La Mancha              81.4917     79.2114     80.2528
#     Cataluña                         84.236     82.9133     83.8838
# ...

# %% [markdown]
# Divido la tabla 'ambos' de tal manera que podemos observar la tasa de actividad total y la tasa de actividad en función del nivel de estudios

# %%
ambos_total = df.iloc[3:22,0:8]
ambos_total=ambos_total.set_axis([2021,2020, 2019,2018,2017,2016,2015,2014], axis=1)
ambos_total
# Out:
#                                     2021     2020     2019     2018     2017  \
#
#     TOTAL                        81.5179  79.9435  81.0298  80.8341  80.8930
#     Andalucía                    78.0396  75.7452  76.9738  76.9808  77.3247
#     Aragón                       83.8101  82.5463  84.0779  83.4287  82.7504
#     Asturias, Principado de      76.6549  75.2735  75.3420  74.9585  74.5826
#     Balears, Illes               83.6156  80.6136  82.7619  83.0605  83.1539
#     Canarias                     77.5728  75.9111  78.7184  78.8328  78.5135
#     Cantabria                    80.5055  78.1394  79.3835  78.4165  78.9740
#     Castilla y León              80.9962  79.9130  81.0874  80.5671  80.5780
#     Castilla-La Mancha           81.4917  79.2114  80.2528  80.4457  80.6792
#     Cataluña                      84.236  82.9133  83.8838  83.4963  84.1133
#     Comunitat Valenciana         80.6572  79.5975  80.8454  80.9559  81.0658
# ...

# %%
ambos_inferior=df.iloc[3:22,8:16]
ambos_inferior=ambos_inferior.set_axis([2021, 2020, 2019,2018,2017,2016,2015,2014], axis=1)
ambos_inferior
# Out:
#                                     2021     2020     2019     2018     2017  \
#
#     TOTAL                        72.5281  70.5776  72.1540  72.2501  72.4639
#     Andalucía                    70.6844  67.1234  69.1908  70.0184  70.9928
#     Aragón                       74.6003  72.4404  75.4619  75.6717  74.8256
#     Asturias, Principado de      62.8801  61.6573  62.4968  61.2081  59.7615
#     Balears, Illes               74.2331  71.2256  77.6902  78.1697  77.3361
#     Canarias                     69.2396  66.7531  70.0997  70.4984  71.0984
#     Cantabria                    69.2096  68.1437  69.4695  68.7835  68.3142
#     Castilla y León              72.6731  71.4827  72.8881  72.1505  72.2905
#     Castilla-La Mancha           75.5496  72.2340  72.8600  74.3234  74.8039
#     Cataluña                     74.4644  73.6109  75.1065  74.1586  74.9646
#     Comunitat Valenciana         73.7518  72.4012  73.0256  73.5786  73.9015
# ...

# %%
ambos_ESO=df.iloc[3:22,16:24]
ambos_ESO=ambos_ESO.set_axis([2021, 2020, 2019,2018,2017,2016,2015,2014], axis=1)
ambos_ESO
# Out:
#                                     2021     2020     2019     2018     2017  \
#
#     TOTAL                        82.2292  80.5433  82.3729  82.2767  82.6470
#     Andalucía                    79.3103  78.8241  80.4411  79.6401  80.0913
#     Aragón                       85.3104  85.5194  85.3839  83.6407  82.3564
#     Asturias, Principado de      76.9738  75.6943  74.0135  75.3952  75.8251
#     Balears, Illes               85.5328  83.7911  82.6770  84.1878  85.2167
#     Canarias                      79.276  76.3338  81.8040  83.6904  81.6239
#     Cantabria                    82.1675  77.8347  80.1066  77.4741  79.1155
#     Castilla y León              82.3335  80.9759  83.0711  83.2331  82.2965
#     Castilla-La Mancha           84.0854  81.3170  83.8108  82.3994  83.7084
#     Cataluña                     84.8334  83.3527  83.6970  84.5489  85.6876
#     Comunitat Valenciana         80.2413  79.7300  83.3219  83.7891  83.4458
# ...

# %%
ambos_superior=df.iloc[3:22,24:32]
ambos_superior=ambos_superior.set_axis([2021, 2020, 2019,2018,2017,2016,2015,2014], axis=1)
ambos_superior
# Out:
#                                     2021     2020     2019     2018     2017  \
#
#     TOTAL                        89.0817  88.3567  89.1357  89.1390  89.2864
#     Andalucía                    86.9224  86.1659  86.5655  86.4030  86.2699
#     Aragón                       89.6156  88.7489  90.7145  90.4532  90.9170
#     Asturias, Principado de      85.9824  84.6190  85.8791  85.3130  86.3146
#     Balears, Illes               91.2458  88.0497  89.4278  88.9844  89.1387
#     Canarias                     85.0941  86.1163  87.6470  87.0352  87.1705
#     Cantabria                    87.6772  85.9190  86.3127  86.4801  87.9172
#     Castilla y León              87.7426  87.3559  88.1303  88.0175  88.8120
#     Castilla-La Mancha           88.3101  88.4323  89.6745  89.7300  89.0259
#     Cataluña                     91.6866  90.6416  91.5010  91.5298  92.3882
#     Comunitat Valenciana         87.6982  86.6586  87.7501  87.5210  88.5336
# ...

# %%
ambos_2021=df.iloc[3,8],df.iloc[3,16],df.iloc[3,24]
ambos_2021
# Out:
# (72.5281, 82.2292, 89.0817)

# %%
ambos_2020=df.iloc[3,9],df.iloc[3,17],df.iloc[3,25]
ambos_2020
# Out:
# (70.5776, 80.5433, 88.3567)

# %%
ambos_2019=df.iloc[3,10],df.iloc[3,18],df.iloc[3,26]
ambos_2019
# Out:
# (72.154, 82.3729, 89.1357)

# %%
ambos_2018=df.iloc[3,11],df.iloc[3,19],df.iloc[3,27]
ambos_2018
# Out:
# (72.2501, 82.2767, 89.139)

# %%
ambos_2017=df.iloc[3,12],df.iloc[3,20],df.iloc[3,28]
ambos_2017
# Out:
# (72.4639, 82.647, 89.2864)

# %%
ambos_2016=df.iloc[3,13],df.iloc[3,21],df.iloc[3,29]
ambos_2016
# Out:
# (72.9031, 83.4573, 89.6099)

# %%
ambos_2015=df.iloc[3,14],df.iloc[3,22],df.iloc[3,30]
ambos_2015
# Out:
# (72.5925, 83.8143, 89.6095)

# %%
ambos_2014=df.iloc[3,15],df.iloc[3,23],df.iloc[3,31]
ambos_2014
# Out:
# (71.9947, 84.0503, 89.6134)

# %% [markdown]
# Saco diferentes tablas con la tasa de actividad de los hombres en función de su edad y sus estudios

# %%
tasa_hombres = df.iloc[3:22,32:40]
tasa_hombres=tasa_hombres.set_axis([2021,2020, 2019,2018,2017,2016,2015,2014], axis=1)
tasa_hombres
# Out:
#                                     2021     2020     2019     2018     2017  \
#
#     TOTAL                        86.3193  85.2813  86.5054  86.6557  86.7011
#     Andalucía                    84.9021  83.5194  84.0673  84.6583  84.9044
#     Aragón                       87.6433  87.0554  89.4606  88.4825  88.6246
#     Asturias, Principado de      80.5425  78.7186  78.3101  78.3810  78.3430
#     Balears, Illes               87.5105  84.8092  87.6657  87.9936  88.7848
#     Canarias                     80.8731  80.2000  83.4035  84.1183  83.3838
#     Cantabria                    85.0686  83.3208  85.8274  85.0534  84.1890
#     Castilla y León              86.1064  85.4596  86.7425  86.3830  86.0193
#     Castilla-La Mancha           88.3801  87.0745  87.4822  88.2452  88.5828
#     Cataluña                     87.8912  87.2457  88.4353  88.4235  88.7385
#     Comunitat Valenciana         85.9565  85.6719  87.4752  87.4827  87.3959
# ...

# %%
tasa_hombres_25_34 = df.iloc[23:24,32:40]
tasa_hombres_25_34=tasa_hombres_25_34.set_axis([2021,2020, 2019,2018,2017,2016,2015,2014], axis=1)
tasa_hombres_25_34= tasa_hombres_25_34.set_axis(['24-34 años'])
tasa_hombres_25_34
# Out:
#                2021     2020     2019     2018     2017    2016     2015  \
# 24-34 años  88.5783  87.0166  89.7411  90.1003  90.2554  91.209  91.6327
#
#                2014
# 24-34 años  92.1583

# %%
tasa_hombres_35_44 = df.iloc[43:44,32:40]
tasa_hombres_35_44=tasa_hombres_35_44.set_axis([2021,2020, 2019,2018,2017,2016,2015,2014], axis=1)
tasa_hombres_35_44=tasa_hombres_35_44.set_axis(['35-44 años'])
tasa_hombres_35_44
# Out:
#                2021     2020     2019     2018     2017     2016     2015  \
# 35-44 años  93.4555  92.4775  93.8632  94.3925  94.4891  94.8654  94.8774
#
#                2014
# 35-44 años  94.6333

# %%
tasa_hombres_45_54 = df.iloc[63:64,32:40]
tasa_hombres_45_54=tasa_hombres_45_54.set_axis([2021,2020, 2019,2018,2017,2016,2015,2014], axis=1)
tasa_hombres_45_54=tasa_hombres_45_54.set_axis(['45-54 años'])
tasa_hombres_45_54
# Out:
#                2021     2020     2019    2018     2017     2016     2015  \
# 45-54 años  91.1606  90.0882  90.9457  90.723  90.6604  90.8422  90.8541
#
#                2014
# 45-54 años  90.5418

# %%
tasa_hombres_55_64 = df.iloc[83:84,32:40]
tasa_hombres_55_64=tasa_hombres_55_64.set_axis([2021,2020, 2019,2018,2017,2016,2015,2014], axis=1)
tasa_hombres_55_64=tasa_hombres_55_64.set_axis(['55-64 años'])
tasa_hombres_55_64
# Out:
#                2021     2020     2019     2018     2017     2016     2015  \
# 55-64 años  70.8672  69.6171  69.1612  68.4463  67.8522  66.9866  66.2482
#
#                2014
# 55-64 años  64.2753

# %%
hombres_edad=pd.concat([tasa_hombres_25_34,tasa_hombres_35_44,tasa_hombres_45_54,tasa_hombres_55_64])
hombres_edad
# Out:
#                2021     2020     2019     2018     2017     2016     2015  \
# 24-34 años  88.5783  87.0166  89.7411  90.1003  90.2554  91.2090  91.6327
# 35-44 años  93.4555  92.4775  93.8632  94.3925  94.4891  94.8654  94.8774
# 45-54 años  91.1606  90.0882  90.9457  90.7230  90.6604  90.8422  90.8541
# 55-64 años  70.8672  69.6171  69.1612  68.4463  67.8522  66.9866  66.2482
#
#                2014
# 24-34 años  92.1583
# 35-44 años  94.6333
# 45-54 años  90.5418
# 55-64 años  64.2753

# %%
hombres_edad.plot(title='Hombres')
# Out:
# <AxesSubplot:title={'center':'Hombres'}>

# %%
hombres_inferior=df.iloc[3:22,40:48]
hombres_inferior=hombres_inferior.set_axis([2021,2020, 2019,2018,2017,2016,2015,2014], axis=1)
hombres_inferior
# Out:
#                                     2021     2020     2019     2018     2017  \
#
#     TOTAL                        81.1546  79.7440  81.1542  81.6738  81.9713
#     Andalucía                    81.2715  79.0175  79.9794  80.8608  81.8003
#     Aragón                       82.9372  80.3988  84.6913  84.4174  83.6108
#     Asturias, Principado de      69.8533  68.6057  68.7306  67.7572  66.5038
#     Balears, Illes               81.9094  79.0789  84.6354  86.2566  86.3238
#     Canarias                     74.8557  74.2309  77.1778  78.3045  78.5787
#     Cantabria                    76.9868  77.0725  80.3532  79.1534  77.1326
#     Castilla y León              81.3314  80.8666  82.7755  82.0680  81.6837
#     Castilla-La Mancha           85.7989  84.4015  84.7101  86.4578  87.0486
#     Cataluña                     82.3644  81.7895  82.9390  82.9594  83.4964
#     Comunitat Valenciana         81.4581  81.2735  82.6824  82.9524  82.9835
# ...

# %%
hombres_inferior_25_34=df.iloc[23:24,40:48]
hombres_inferior_25_34=hombres_inferior_25_34.set_axis([2021,2020, 2019,2018,2017,2016,2015,2014], axis=1)
hombres_inferior_25_34=hombres_inferior_25_34.set_axis(['24-34 años'])
hombres_inferior_25_34
hombres_inferior_35_44 = df.iloc[43:44,40:48]
hombres_inferior_35_44=hombres_inferior_35_44.set_axis([2021,2020, 2019,2018,2017,2016,2015,2014], axis=1)
hombres_inferior_35_44=hombres_inferior_35_44.set_axis(['35-44 años'])
hombres_inferior_35_44
hombres_inferior_45_54 = df.iloc[63:64,40:48]
hombres_inferior_45_54=hombres_inferior_45_54.set_axis([2021,2020, 2019,2018,2017,2016,2015,2014], axis=1)
hombres_inferior_45_54=hombres_inferior_45_54.set_axis(['45-54 años'])
hombres_inferior_45_54
hombres_inferior_55_64 = df.iloc[83:84,40:48]
hombres_inferior_55_64=hombres_inferior_55_64.set_axis([2021,2020, 2019,2018,2017,2016,2015,2014], axis=1)
hombres_inferior_55_64=hombres_inferior_55_64.set_axis(['55-64 años'])
hombres_inferior_55_64

hombres_inferior_edad=pd.concat([hombres_inferior_25_34,hombres_inferior_35_44,hombres_inferior_45_54,hombres_inferior_55_64])
hombres_inferior_edad
# Out:
#                2021     2020     2019     2018     2017     2016     2015  \
# 24-34 años  87.0868  86.1687  89.7442  90.6171  90.9788  92.3199  92.4140
# 35-44 años  89.5764  88.1987  89.8485  90.8568  91.5249  91.9303  91.9671
# 45-54 años  86.8394  85.4567  86.1078  85.8270  85.8881  86.5776  87.1457
# 55-64 años  65.2055  63.0769  63.2830  63.4251  62.9948  62.2397  61.0829
#
#                2014
# 24-34 años  92.5343
# 35-44 años  91.2040
# 45-54 años  86.7536
# 55-64 años  59.4791

# %%
fig, ax = plt.subplots()
ax.set_title('Educación inferior')
ax.plot(hombres_inferior_edad)
plt.ylim(40,100)
plt.show()

# %%
hombres_ESO=df.iloc[3:22,48:56]
hombres_ESO=hombres_ESO.set_axis([2021,2020, 2019,2018,2017,2016,2015,2014], axis=1)
hombres_ESO
# Out:
#                                     2021     2020     2019     2018     2017  \
#
#     TOTAL                        87.2059  85.9079  87.9804  87.7555  87.8376
#     Andalucía                    85.6335  85.2734  86.0408  86.4892  86.5540
#     Aragón                       89.3546  90.6063  91.8716  89.1891  89.3213
#     Asturias, Principado de      80.4812  78.8784  78.0967  79.0529  81.2994
#     Balears, Illes               88.8031  85.6869  87.1801  87.7694  90.4408
#     Canarias                     83.4989  80.4810  86.5149  88.2471  86.8011
#     Cantabria                    87.0116  83.0691  85.7996  84.8213  87.3043
#     Castilla y León              86.7591  86.0289  88.2072  88.5770  87.3341
#     Castilla-La Mancha           91.1565  88.4245  88.9740  88.1403  88.7634
#     Cataluña                     88.5523  87.7574  89.3341  89.5374  88.9385
#     Comunitat Valenciana         86.6744  86.5544  89.4253  89.1925  88.9422
# ...

# %%
hombres_ESO_25_34=df.iloc[23:24,48:56]
hombres_ESO_25_34=hombres_ESO_25_34.set_axis([2021,2020, 2019,2018,2017,2016,2015,2014], axis=1)
hombres_ESO_25_34=hombres_ESO_25_34.set_axis(['24-34 años'])
hombres_ESO_25_34
hombres_ESO_35_44 = df.iloc[43:44,48:56]
hombres_ESO_35_44=hombres_ESO_35_44.set_axis([2021,2020, 2019,2018,2017,2016,2015,2014], axis=1)
hombres_ESO_35_44=hombres_ESO_35_44.set_axis(['35-44 años'])
hombres_ESO_35_44
hombres_ESO_45_54 = df.iloc[63:64,48:56]
hombres_ESO_45_54=hombres_ESO_45_54.set_axis([2021,2020, 2019,2018,2017,2016,2015,2014], axis=1)
hombres_ESO_45_54=hombres_ESO_45_54.set_axis(['45-54 años'])
hombres_ESO_45_54
hombres_ESO_55_64 = df.iloc[83:84,48:56]
hombres_ESO_55_64=hombres_ESO_55_64.set_axis([2021,2020, 2019,2018,2017,2016,2015,2014], axis=1)
hombres_ESO_55_64=hombres_ESO_55_64.set_axis(['55-64 años'])
hombres_ESO_55_64

hombres_ESO_edad=pd.concat([hombres_ESO_25_34,hombres_ESO_35_44,hombres_ESO_45_54,hombres_ESO_55_64])
hombres_ESO_edad
# Out:
#                2021     2020     2019     2018     2017     2016     2015  \
# 24-34 años  85.8392  83.7111  87.1250  87.2205  87.5360  88.5654  89.4524
# 35-44 años  95.1395  93.3763  94.9507  95.1399  94.0211  95.8157  95.7383
# 45-54 años  92.7192  90.7876  92.7976  92.6917  93.2269  92.3021  92.2707
# 55-64 años  72.5703  72.3405  72.5277  70.4859  70.7928  70.1358  70.4663
#
#                2014
# 24-34 años  90.6640
# 35-44 años  95.2241
# 45-54 años  92.1234
# 55-64 años  68.2763

# %%
fig, ax = plt.subplots()
ax.set_title('Educación secundaria')
ax.plot(hombres_ESO_edad)
plt.ylim(40,100)
plt.show()

# %%
hombres_superior=df.iloc[3:22,56:64]
hombres_superior=hombres_superior.set_axis([2021,2020, 2019,2018,2017,2016,2015,2014], axis=1)
hombres_superior
# Out:
#                                     2021     2020     2019     2018     2017  \
#
#     TOTAL                        91.2288  90.9598  91.8058  92.0884  92.0347
#     Andalucía                    90.1137  89.8526  89.7214  90.2357  89.7477
#     Aragón                       90.5942  90.6652  92.3879  92.2700  93.6960
#     Asturias, Principado de      88.6273  86.8029  86.8029  87.2199  87.4551
#     Balears, Illes                93.205  91.6862  93.0973  91.3815  91.1641
#     Canarias                     86.5953  88.2974  90.1911  90.1157  88.7160
#     Cantabria                    90.8217  89.0334  90.7703  90.7299  89.1265
#     Castilla y León              91.4284  90.4558  90.6605  90.6434  91.1403
#     Castilla-La Mancha           90.7706  91.0530  91.5371  91.9938  91.7919
#     Cataluña                     92.7039  92.2590  93.4695  93.5728  94.6238
#     Comunitat Valenciana         90.7265  90.3758  92.4393  92.5695  92.8705
# ...

# %%
hombres_superior_25_34=df.iloc[23:24,56:64]
hombres_superior_25_34=hombres_superior_25_34.set_axis([2021,2020, 2019,2018,2017,2016,2015,2014], axis=1)
hombres_superior_25_34=hombres_superior_25_34.set_axis(['24-34 años'])
hombres_superior_25_34
hombres_superior_35_44 = df.iloc[43:44,56:64]
hombres_superior_35_44=hombres_superior_35_44.set_axis([2021,2020, 2019,2018,2017,2016,2015,2014], axis=1)
hombres_superior_35_44=hombres_superior_35_44.set_axis(['35-44 años'])
hombres_superior_35_44
hombres_superior_45_54 = df.iloc[63:64,56:64]
hombres_superior_45_54=hombres_superior_45_54.set_axis([2021,2020, 2019,2018,2017,2016,2015,2014], axis=1)
hombres_superior_45_54=hombres_superior_45_54.set_axis(['45-54 años'])
hombres_superior_45_54
hombres_superior_55_64 = df.iloc[83:84,56:64]
hombres_superior_55_64=hombres_superior_55_64.set_axis([2021,2020, 2019,2018,2017,2016,2015,2014], axis=1)
hombres_superior_55_64=hombres_superior_55_64.set_axis(['55-64 años'])
hombres_superior_55_64

hombres_superior_edad=pd.concat([hombres_superior_25_34,hombres_superior_35_44,hombres_superior_45_54,hombres_superior_55_64])
hombres_superior_edad
# Out:
#                2021     2020     2019     2018     2017     2016     2015  \
# 24-34 años  91.2441  89.7122  91.2798  91.3676  91.2780  91.7621  92.2848
# 35-44 años  95.9345  95.7758  96.9863  97.2537  97.5737  97.1157  97.1983
# 45-54 años  94.8484  94.8945  95.6221  95.7724  95.4377  96.0015  95.6921
# 55-64 años   78.757  78.7382  77.5738  77.0701  75.9412  75.1435  74.4731
#
#                2014
# 24-34 años  92.7695
# 35-44 años  97.7175
# 45-54 años  95.3377
# 55-64 años  72.6434

# %%
fig, ax = plt.subplots()
ax.set_title('Educación superior')
ax.plot(hombres_superior_edad)
plt.ylim(40,100)
plt.show()

# %% [markdown]
# Saco las mismas tablas pero con las mujeres

# %%
tasa_mujeres = df.iloc[3:22,64:72]
tasa_mujeres=tasa_mujeres.set_axis([2021,2020, 2019,2018,2017,2016,2015,2014], axis=1)
tasa_mujeres
# Out:
#                                     2021     2020     2019     2018     2017  \
#
#     TOTAL                        76.7683  74.6574  75.5999  75.0538  75.1151
#     Andalucía                    71.2234  68.0148  69.9072  69.3202  69.7412
#     Aragón                       79.9138  77.9436  78.5793  78.2556  76.7247
#     Asturias, Principado de      72.8835  71.9304  72.4594  71.6318  70.9237
#     Balears, Illes                79.636  76.3112  77.7360  78.0116  77.4022
#     Canarias                     74.2854  71.6243  74.0258  73.5326  73.6251
#     Cantabria                    75.9807  73.0002  72.9873  71.8143  73.7808
#     Castilla y León              75.7688  74.2267  75.2746  74.5713  74.9498
#     Castilla-La Mancha           74.2481  70.9316  72.6379  72.2151  72.3106
#     Cataluña                     80.6469  78.6576  79.4091  78.6540  79.5631
#     Comunitat Valenciana          75.377  73.5345  74.2173  74.4161  74.7109
# ...

# %%
tasa_mujeres_25_34 = df.iloc[23:24,64:72]
tasa_mujeres_25_34=tasa_mujeres_25_34.set_axis([2021,2020, 2019,2018,2017,2016,2015,2014], axis=1)
tasa_mujeres_25_34= tasa_mujeres_25_34.set_axis(['24-34 años'])
tasa_mujeres_25_34
# Out:
#                2021     2020     2019     2018     2017     2016     2015  \
# 24-34 años  84.0359  81.7418  82.7129  83.0034  83.6706  84.2642  85.0725
#
#                2014
# 24-34 años  86.0565

# %%
tasa_mujeres_35_44 = df.iloc[43:44,64:72]
tasa_mujeres_35_44=tasa_mujeres_35_44.set_axis([2021,2020, 2019,2018,2017,2016,2015,2014], axis=1)
tasa_mujeres_35_44=tasa_mujeres_35_44.set_axis(['35-44 años'])
tasa_mujeres_35_44
# Out:
#                2021     2020     2019     2018     2017     2016     2015  \
# 35-44 años  85.3669  83.1884  84.9386  84.7743  85.3468  85.6464  84.6076
#
#                2014
# 35-44 años  84.3968

# %%
tasa_mujeres_45_54 = df.iloc[63:64,64:72]
tasa_mujeres_45_54=tasa_mujeres_45_54.set_axis([2021,2020, 2019,2018,2017,2016,2015,2014], axis=1)
tasa_mujeres_45_54=tasa_mujeres_45_54.set_axis(['45-54 años'])
tasa_mujeres_45_54
# Out:
#                2021     2020     2019     2018     2017     2016     2015  \
# 45-54 años  80.0773  77.9357  79.2934  77.9194  77.3332  77.2862  76.8094
#
#                2014
# 45-54 años  75.9111

# %%
tasa_mujeres_55_64 = df.iloc[83:84,64:72]
tasa_mujeres_55_64=tasa_mujeres_55_64.set_axis([2021,2020, 2019,2018,2017,2016,2015,2014], axis=1)
tasa_mujeres_55_64=tasa_mujeres_55_64.set_axis(['55-64 años'])
tasa_mujeres_55_64
# Out:
#                2021     2020     2019     2018     2017     2016    2015  \
# 55-64 años  58.2826  55.6739  54.4251  52.8906  51.7932  51.6697  49.392
#
#                2014
# 55-64 años  46.8965

# %%
mujeres_edad=pd.concat([tasa_mujeres_25_34,tasa_mujeres_35_44,tasa_mujeres_45_54,tasa_mujeres_55_64])
mujeres_edad
# Out:
#                2021     2020     2019     2018     2017     2016     2015  \
# 24-34 años  84.0359  81.7418  82.7129  83.0034  83.6706  84.2642  85.0725
# 35-44 años  85.3669  83.1884  84.9386  84.7743  85.3468  85.6464  84.6076
# 45-54 años  80.0773  77.9357  79.2934  77.9194  77.3332  77.2862  76.8094
# 55-64 años  58.2826  55.6739  54.4251  52.8906  51.7932  51.6697  49.3920
#
#                2014
# 24-34 años  86.0565
# 35-44 años  84.3968
# 45-54 años  75.9111
# 55-64 años  46.8965

# %%
mujeres_edad.plot(title='Mujeres')
# Out:
# <AxesSubplot:title={'center':'Mujeres'}>

# %%
mujeres_inferior=df.iloc[3:4,72:80]
mujeres_inferior=mujeres_inferior.set_axis([2021,2020, 2019,2018,2017,2016,2015,2014], axis=1)
mujeres_inferior
# Out:
#               2021     2020     2019     2018     2017    2016     2015  \
#
#     TOTAL  62.2367  59.8573  61.7346  61.4434  61.7271  62.047  61.4597
#
#               2014
#
#     TOTAL  61.0158

# %%
mujeres_inferior_25_34=df.iloc[23:24,72:80]
mujeres_inferior_25_34=mujeres_inferior_25_34.set_axis([2021,2020, 2019,2018,2017,2016,2015,2014], axis=1)
mujeres_inferior_25_34=mujeres_inferior_25_34.set_axis(['24-34 años'])
mujeres_inferior_25_34
mujeres_inferior_35_44 = df.iloc[43:44,72:80]
mujeres_inferior_35_44=mujeres_inferior_35_44.set_axis([2021,2020, 2019,2018,2017,2016,2015,2014], axis=1)
mujeres_inferior_35_44=mujeres_inferior_35_44.set_axis(['35-44 años'])
mujeres_inferior_35_44
mujeres_inferior_45_54 = df.iloc[63:64,72:80]
mujeres_inferior_45_54=mujeres_inferior_45_54.set_axis([2021,2020, 2019,2018,2017,2016,2015,2014], axis=1)
mujeres_inferior_45_54=mujeres_inferior_45_54.set_axis(['45-54 años'])
mujeres_inferior_45_54
mujeres_inferior_55_64 = df.iloc[83:84,72:80]
mujeres_inferior_55_64=mujeres_inferior_55_64.set_axis([2021,2020, 2019,2018,2017,2016,2015,2014], axis=1)
mujeres_inferior_55_64=mujeres_inferior_55_64.set_axis(['55-64 años'])
mujeres_inferior_55_64

mujeres_inferior_edad=pd.concat([mujeres_inferior_25_34,mujeres_inferior_35_44,mujeres_inferior_45_54,mujeres_inferior_55_64])
mujeres_inferior_edad
# Out:
#                2021     2020     2019     2018     2017     2016     2015  \
# 24-34 años  73.7037  72.2131  72.8048  74.9161  75.9057  76.8815  77.0040
# 35-44 años  75.3767  72.2918  75.5873  74.8884  76.1235  75.9409  75.5371
# 45-54 años  68.1313  65.5058  68.1039  67.0186  66.9940  67.3263  66.9279
# 55-64 años  45.5278  43.4770  43.7896  42.6576  41.6196  41.7282  40.0727
#
#                2014
# 24-34 años  79.2875
# 35-44 años  75.5487
# 45-54 años  66.6174
# 55-64 años  37.6720

# %%
fig, ax = plt.subplots()
ax.set_title('Educación inferior')
ax.plot(mujeres_inferior_edad)
plt.ylim(40,100)
plt.show()

# %%
mujeres_ESO=df.iloc[3:4,80:88]
mujeres_ESO=mujeres_ESO.set_axis([2021,2020, 2019,2018,2017,2016,2015,2014], axis=1)
mujeres_ESO
# Out:
#               2021     2020     2019     2018     2017     2016     2015  \
#
#     TOTAL  77.3163  75.2746  76.9261  76.9617  77.4843  78.4187  78.4507
#
#               2014
#
#     TOTAL  79.2434

# %%
mujeres_ESO_25_34=df.iloc[23:24,80:88]
mujeres_ESO_25_34=mujeres_ESO_25_34.set_axis([2021,2020, 2019,2018,2017,2016,2015,2014], axis=1)
mujeres_ESO_25_34=mujeres_ESO_25_34.set_axis(['24-34 años'])
mujeres_ESO_25_34
mujeres_ESO_35_44 = df.iloc[43:44,80:88]
mujeres_ESO_35_44=mujeres_ESO_35_44.set_axis([2021,2020, 2019,2018,2017,2016,2015,2014], axis=1)
mujeres_ESO_35_44=mujeres_ESO_35_44.set_axis(['35-44 años'])
mujeres_ESO_35_44
mujeres_ESO_45_54 = df.iloc[63:64,80:88]
mujeres_ESO_45_54=mujeres_ESO_45_54.set_axis([2021,2020, 2019,2018,2017,2016,2015,2014], axis=1)
mujeres_ESO_45_54=mujeres_ESO_45_54.set_axis(['45-54 años'])
mujeres_ESO_45_54
mujeres_ESO_55_64 = df.iloc[83:84,80:88]
mujeres_ESO_55_64=mujeres_ESO_55_64.set_axis([2021,2020, 2019,2018,2017,2016,2015,2014], axis=1)
mujeres_ESO_55_64=mujeres_ESO_55_64.set_axis(['55-64 años'])
mujeres_ESO_55_64

mujeres_ESO_edad=pd.concat([mujeres_ESO_25_34,mujeres_ESO_35_44,mujeres_ESO_45_54,mujeres_ESO_55_64])
mujeres_ESO_edad
# Out:
#                2021     2020     2019     2018     2017     2016     2015  \
# 24-34 años  82.7609  79.5676  82.5156  81.4815  81.9918  83.3273  83.9212
# 35-44 años  83.2024  81.2362  83.4723  83.9993  84.8858  85.6363  83.9505
# 45-54 años  80.3211  79.0647  80.7431  79.8908  79.5928  79.6877  80.0593
# 55-64 años  63.4301  60.0799  58.8319  59.2300  59.2212  59.7819  59.0150
#
#                2014
# 24-34 años  85.4019
# 35-44 años  85.1746
# 45-54 años  79.4097
# 55-64 años  58.6140

# %%
fig, ax = plt.subplots()
ax.set_title('Educación secundaria')
ax.plot(mujeres_ESO_edad)
plt.ylim(40,100)
plt.show()

# %%
mujeres_superior=df.iloc[3:4,88:96]
mujeres_superior=mujeres_superior.set_axis([2021,2020, 2019,2018,2017,2016,2015,2014], axis=1)
mujeres_superior
# Out:
#               2021     2020     2019     2018     2017    2016     2015  \
#
#     TOTAL  87.2807  86.1398  86.8406  86.5932  86.9161  87.486  87.5526
#
#               2014
#
#     TOTAL  87.3257

# %%
mujeres_superior_25_34=df.iloc[23:24,88:96]
mujeres_superior_25_34=mujeres_superior_25_34.set_axis([2021,2020, 2019,2018,2017,2016,2015,2014], axis=1)
mujeres_superior_25_34=mujeres_superior_25_34.set_axis(['24-34 años'])
mujeres_superior_25_34
mujeres_superior_35_44 = df.iloc[43:44,80:88]
mujeres_superior_35_44=mujeres_superior_35_44.set_axis([2021,2020, 2019,2018,2017,2016,2015,2014], axis=1)
mujeres_superior_35_44=mujeres_superior_35_44.set_axis(['35-44 años'])
mujeres_superior_35_44
mujeres_superior_45_54 = df.iloc[63:64,80:88]
mujeres_superior_45_54=mujeres_superior_45_54.set_axis([2021,2020, 2019,2018,2017,2016,2015,2014], axis=1)
mujeres_superior_45_54=mujeres_superior_45_54.set_axis(['45-54 años'])
mujeres_superior_45_54
mujeres_superior_55_64 = df.iloc[83:84,80:88]
mujeres_superior_55_64=mujeres_superior_55_64.set_axis([2021,2020, 2019,2018,2017,2016,2015,2014], axis=1)
mujeres_superior_55_64=mujeres_superior_55_64.set_axis(['55-64 años'])
mujeres_superior_55_64

mujeres_superior_edad=pd.concat([mujeres_superior_25_34,mujeres_superior_35_44,mujeres_superior_45_54,mujeres_superior_55_64])
mujeres_superior_edad
# Out:
#                2021     2020     2019     2018     2017     2016     2015  \
# 24-34 años  88.8255  86.7747  87.4827  88.0237  88.9542  89.2851  90.5759
# 35-44 años  83.2024  81.2362  83.4723  83.9993  84.8858  85.6363  83.9505
# 45-54 años  80.3211  79.0647  80.7431  79.8908  79.5928  79.6877  80.0593
# 55-64 años  63.4301  60.0799  58.8319  59.2300  59.2212  59.7819  59.0150
#
#                2014
# 24-34 años  90.4856
# 35-44 años  85.1746
# 45-54 años  79.4097
# 55-64 años  58.6140

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()
ax.set_title('Educación superior')
ax.plot(mujeres_superior_edad)
plt.ylim(40,100)
plt.show()

# %%
ambos_total=pd.DataFrame([['2021',df.iloc[3,8],df.iloc[3,16],df.iloc[3,24]],
                 ['2020',df.iloc[3,9],df.iloc[3,17],df.iloc[3,25]],
                 ['2019',df.iloc[3,10],df.iloc[3,18],df.iloc[3,26]],
                 ['2018',df.iloc[3,11],df.iloc[3,19],df.iloc[3,27]],
                 ['2017',df.iloc[3,12],df.iloc[3,20],df.iloc[3,28]],
                 ['2016',df.iloc[3,13],df.iloc[3,21],df.iloc[3,29]],
                 ['2015',df.iloc[3,14],df.iloc[3,22],df.iloc[3,28]],
                 ['2014',df.iloc[3,15],df.iloc[3,23],df.iloc[3,31]]
                ],columns=['año','educación inferior','educación secundaria','educación superior'], 
               )
ambos_total
# Out:
#     año  educación inferior  educación secundaria  educación superior
# 0  2021             72.5281               82.2292             89.0817
# 1  2020             70.5776               80.5433             88.3567
# 2  2019             72.1540               82.3729             89.1357
# 3  2018             72.2501               82.2767             89.1390
# 4  2017             72.4639               82.6470             89.2864
# 5  2016             72.9031               83.4573             89.6099
# 6  2015             72.5925               83.8143             89.2864
# 7  2014             71.9947               84.0503             89.6134

# %%
t_hombres=pd.DataFrame([['2021',df.iloc[3,40],df.iloc[3,48],df.iloc[3,56]],
                 ['2020',df.iloc[3,41],df.iloc[3,49],df.iloc[3,57]],
                 ['2019',df.iloc[3,42],df.iloc[3,50],df.iloc[3,58]],
                 ['2018',df.iloc[3,43],df.iloc[3,51],df.iloc[3,59]],
                 ['2017',df.iloc[3,44],df.iloc[3,52],df.iloc[3,60]],
                 ['2016',df.iloc[3,45],df.iloc[3,53],df.iloc[3,61]],
                 ['2015',df.iloc[3,46],df.iloc[3,54],df.iloc[3,62]],
                 ['2014',df.iloc[3,47],df.iloc[3,55],df.iloc[3,63]]
                ],columns=['año','h-educación inferior','h-educación secundaria','h-educación superior'], 
               )
t_hombres=t_hombres.set_index('año')
t_hombres
# Out:
#       h-educación inferior  h-educación secundaria  h-educación superior
# año
# 2021               81.1546                 87.2059               91.2288
# 2020               79.7440                 85.9079               90.9598
# 2019               81.1542                 87.9804               91.8058
# 2018               81.6738                 87.7555               92.0884
# 2017               81.9713                 87.8376               92.0347
# 2016               82.5156                 88.4636               92.0904
# 2015               82.6729                 89.0342               91.9723
# 2014               82.0890                 88.8112               92.1569

# %%
t_hombres.plot(title='Tasa de actividad hombres')
# Out:
# <AxesSubplot:title={'center':'Tasa de actividad hombres'}, xlabel='año'>

# %%
t_hombres.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='año'>

# %%
t_mujeres=pd.DataFrame([['2021',df.iloc[3,72],df.iloc[3,80],df.iloc[3,88]],
                 ['2020',df.iloc[3,73],df.iloc[3,81],df.iloc[3,89]],
                 ['2019',df.iloc[3,74],df.iloc[3,82],df.iloc[3,90]],
                 ['2018',df.iloc[3,75],df.iloc[3,83],df.iloc[3,91]],
                 ['2017',df.iloc[3,76],df.iloc[3,84],df.iloc[3,92]],
                 ['2016',df.iloc[3,77],df.iloc[3,85],df.iloc[3,93]],
                 ['2015',df.iloc[3,78],df.iloc[3,86],df.iloc[3,94]],
                 ['2014',df.iloc[3,79],df.iloc[3,87],df.iloc[3,95]]
                ],columns=['año','m-educación inferior','m-educación secundaria','m-educación superior'], 
               )
t_mujeres=t_mujeres.set_index('año')
t_mujeres
# Out:
#       m-educación inferior  m-educación secundaria  m-educación superior
# año
# 2021               62.2367                 77.3163               87.2807
# 2020               59.8573                 75.2746               86.1398
# 2019               61.7346                 76.9261               86.8406
# 2018               61.4434                 76.9617               86.5932
# 2017               61.7271                 77.4843               86.9161
# 2016               62.0470                 78.4187               87.4860
# 2015               61.4597                 78.4507               87.5526
# 2014               61.0158                 79.2434               87.3257

# %%
t_mujeres.plot(title='Tasa de actividad mujeres')
# Out:
# <AxesSubplot:title={'center':'Tasa de actividad mujeres'}, xlabel='año'>

# %%
t_hombres_y_mujeres=pd.concat([t_mujeres, t_hombres], axis=1)
t_hombres_y_mujeres
# Out:
#       m-educación inferior  m-educación secundaria  m-educación superior  \
# año
# 2021               62.2367                 77.3163               87.2807
# 2020               59.8573                 75.2746               86.1398
# 2019               61.7346                 76.9261               86.8406
# 2018               61.4434                 76.9617               86.5932
# 2017               61.7271                 77.4843               86.9161
# 2016               62.0470                 78.4187               87.4860
# 2015               61.4597                 78.4507               87.5526
# 2014               61.0158                 79.2434               87.3257
#
#       h-educación inferior  h-educación secundaria  h-educación superior
# año
# 2021               81.1546                 87.2059               91.2288
# 2020               79.7440                 85.9079               90.9598
# 2019               81.1542                 87.9804               91.8058
# ...

# %%
pd.merge(t_mujeres, t_hombres, on='año', suffixes=('_m', '_h'))
# Out:
#       m-educación inferior  m-educación secundaria  m-educación superior  \
# año
# 2021               62.2367                 77.3163               87.2807
# 2020               59.8573                 75.2746               86.1398
# 2019               61.7346                 76.9261               86.8406
# 2018               61.4434                 76.9617               86.5932
# 2017               61.7271                 77.4843               86.9161
# 2016               62.0470                 78.4187               87.4860
# 2015               61.4597                 78.4507               87.5526
# 2014               61.0158                 79.2434               87.3257
#
#       h-educación inferior  h-educación secundaria  h-educación superior
# año
# 2021               81.1546                 87.2059               91.2288
# 2020               79.7440                 85.9079               90.9598
# 2019               81.1542                 87.9804               91.8058
# ...

# %%
ambos_total.corr()
# Out:
#                       educación inferior  educación secundaria  \
# educación inferior              1.000000              0.723139
# educación secundaria            0.723139              1.000000
# educación superior              0.814189              0.931712
#
#                       educación superior
# educación inferior              0.814189
# educación secundaria            0.931712
# educación superior              1.000000

# %%
t_hombres_y_mujeres.plot(color=['g','g','g','b','b','b'],legend=False)
# Out:
# <AxesSubplot:xlabel='año'>

# %%
ambos_total.corr(method='spearman')
# Out:
#                       educación inferior  educación secundaria  \
# educación inferior              1.000000              0.309524
# educación secundaria            0.309524              1.000000
# educación superior              0.335335              0.934148
#
#                       educación superior
# educación inferior              0.335335
# educación secundaria            0.934148
# educación superior              1.000000

# %%
ambos_total.plot.scatter(x=['educación inferior'],y='año');

# %%
ambos_total.plot.scatter(x=['educación superior'],y='año');

# %%
ambos_total.plot.scatter(x=['ESO'],y='año');
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [46], in <cell line: 1>()
# ----> 1 ambos_total.plot.scatter(x=['ESO'],y='año')
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_core.py:1669, in PlotAccessor.scatter(self, x, y, s, c, **kwargs)
#    1586 def scatter(self, x, y, s=None, c=None, **kwargs):
#    1587     """
#    1588     Create a scatter plot with varying marker point size and color.
#    1589
#    (...)
#    1667         ...                       colormap='viridis')
#    1668     """
# -> 1669     return self(kind="scatter", x=x, y=y, s=s, c=c, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_core.py:917, in PlotAccessor.__call__(self, *args, **kwargs)
#     915 if kind in self._dataframe_kinds:
#     916     if isinstance(data, ABCDataFrame):
# --> 917         return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
# ...

# %%
fig, ax = plt.subplots()
for species in set(data.species):
    ax.scatter(
        data.sepal_length[data.species == species],
        data.sepal_width[data.species == species],
        s = 30,
        c = colors[species],
        label = species)
plt.legend()
plt.show()

# %%
# Significancia de la correlación
from scipy.stats import pearsonr
pearsonr(ambos_total['educación inferior'],ambos_total['educación superior'])

# %%
ambos_total_nivel=pd.DataFrame([['2021',df.iloc[3,8],0],
                         ['2021',df.iloc[3,16],1],
                           ['2021',df.iloc[3,24],2],
                 ['2020',df.iloc[3,9],0],
                  ['2020',df.iloc[3,17],1],
                  ['2020',df.iloc[3,25],2],
                 ['2019',df.iloc[3,10],0],
                  ['2019',df.iloc[3,18],1],
                  ['2019',df.iloc[3,26],2],
                 ['2018',df.iloc[3,12],0],
                  ['2018',df.iloc[3,19],1],
                  ['2018',df.iloc[3,27],2],
                 ['2017',df.iloc[3,12],0],
                  ['2017',df.iloc[3,20],1],
                  ['2017',df.iloc[3,28],2],
                          ['2016',df.iloc[3,13],0],
                           ['2016',df.iloc[3,21],1],
                           ['2016',df.iloc[3,29],2],
                 ['2015',df.iloc[3,14],0],
                  ['2015',df.iloc[3,22],1],
                  ['2015',df.iloc[3,28],2],
                 ['2014',df.iloc[3,15],0],
                  ['2014',df.iloc[3,23],1],
                  ['2014',df.iloc[3,31],2]
                
                ],columns=['año','tasa actividad','nivel de estudios'], 
               )
ambos_total_nivel

# %%
import seaborn as sns
sns.scatterplot(data=ambos_total_nivel,x='tasa actividad',y='tasa actividad',hue='nivel de estudios',palette='tab10');

# %%
ambos_total_nivel.corr()

# %%
ambos_total_nivel.corr(method='spearman')

# %%
ambos_total_nivel.plot.scatter(x='tasa actividad',y='nivel de estudios');

# %%
ambos_total_nivel.plot.bar(y='tasa actividad',x='nivel de estudios',color=['r','g','b']*8);

# %%
df2 = pd.read_excel('C:/Users/vgonz/Documents/the bridge/prueba_git/02-Data_analysis/proyecto eda empleabilidad/Nivel de formación de la población adulta por grupos de edad. CNED-2014.xlsx', engine='openpyxl')
df2=df2.rename(index={1:'educacion_inferior',5:'educacion_inferior',9:'educacion_inferior',13:'educacion_inferior',17:'educacion_inferior'})
df2=df2.rename(index={2:'educación_secundaria',6:'educación_secundaria',10:'educación_secundaria',14:'educación_secundaria',18:'educación_secundaria'})
df2=df2.rename(index={3:'educacion_superior',7:'educacion_superior',11:'educacion_superior',15:'educacion_superior',19:'educacion_superior'})
df2=df2.rename(index={0:'total',4:'25-34',8:'35-44',12:'45-54',16:'55-64'})
df2=df2.drop(['AÑO'], axis=1)
df2

# %%
hombres=df2.iloc[0:50,0:9]
hombres

# %%
mujeres=df2.iloc[0:50,8:50]
mujeres

# %%
mujeres_total=df2.iloc[1:4,8:50]
mujeres_total=mujeres_total.reset_index()
mujeres_total=mujeres_total.rename(columns={'index':'nivel_estudios'})
mujeres_total

# %%
nivel_formacion = mujeres_total.melt(id_vars=['nivel_estudios'],var_name='año')
nivel_formacion

# %%
nivel_formacion_2021=nivel_formacion.iloc[0:3]
nivel_formacion_2021

# %%
nivel_formacion_2021['value'].plot(kind='pie',title='Nivel Estudios Mujeres',autopct='%1.1f%%',labels=nivel_formacion['nivel_estudios'])
labels=nivel_formacion['nivel_estudios']

# %%
nivel_formacion_2021['value'].plot(kind='bar',title='Nivel Estudios',)

# %%
nivel_formacion_2020=nivel_formacion.iloc[3:6]
nivel_formacion_2020

# %%
nivel_formacion_2019['value'].plot(kind='bar',title='Nivel Estudios',)

# %%
hombres_total=df2.iloc[1:4,0:9]
hombres_total=hombres_total.reset_index()
hombres_total=hombres_total.rename(columns={'index':'nivel_estudios'})
hombres_total

# %%
nivel_formacion_hombres = hombres_total.melt(id_vars=['nivel_estudios'],var_name='año')
nivel_formacion_hombres

# %%
nivel_formacion_2021_hombres=nivel_formacion_hombres.iloc[0:3]
nivel_formacion_2021_hombres

# %%
nivel_formacion_2021_hombres['value'].plot(kind='pie',title='Nivel Estudios Hombres',autopct='%1.1f%%',labels=nivel_formacion['nivel_estudios'])
labels=nivel_formacion['nivel_estudios']

# %%
nivel_formacion_2021_hombres['value'].plot(kind='bar',title='Nivel Estudios',)
